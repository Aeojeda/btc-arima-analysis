# %% [markdown]
# # Ver notebook principal bitcoin_arima_analysis.ipynb
#
# Este capítulo corresponde a la sección del notebook principal. Los resultados y código están en `bitcoin_arima_analysis.ipynb`.
